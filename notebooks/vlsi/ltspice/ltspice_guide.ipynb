# %% [markdown]
# <a href="https://colab.research.google.com/github/venkataratnamb20/quicksilicon/blob/notebooks/notebooks/vlsi/ltspice/ltspice_guide.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LTSpice

# %%
# !ngspice --version && apt install ngspice
# Out:
# ******
# ** ngspice-36 : Circuit level simulation program
# ** The U. C. Berkeley CAD Group
# ** Copyright 1985-1994, Regents of the University of California.
# ** Copyright 2001-2020, The ngspice team.
# ** Please get your ngspice manual from http://ngspice.sourceforge.net/docs.html
# ** Please file your bug-reports at http://ngspice.sourceforge.net/bugrep.html
# ** Creation Date: Mon Mar 11 21:44:53 UTC 2024
# ******
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ngspice is already the newest version (36+ds-1ubuntu0.1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.

# %% [markdown]
# ## Setup

# %%
# %%shell
#
# pwd
#
# ls -al
#
# python --version
# git --version
# Out:
# /content
# total 16
# drwxr-xr-x 1 root root 4096 Aug 14 13:22 .
# drwxr-xr-x 1 root root 4096 Aug 19 07:07 ..
# drwxr-xr-x 4 root root 4096 Aug 14 13:22 .config
# drwxr-xr-x 1 root root 4096 Aug 14 13:23 sample_data
# Python 3.10.12
# git version 2.34.1

# %%
# !pwd
# !ls -al

print("Welcome to Python")
# Out:
# /content
# total 16
# drwxr-xr-x 1 root root 4096 Aug 14 13:22 .
# drwxr-xr-x 1 root root 4096 Aug 19 07:07 ..
# drwxr-xr-x 4 root root 4096 Aug 14 13:22 .config
# drwxr-xr-x 1 root root 4096 Aug 14 13:23 sample_data
# Welcome to Python

# %%
def print_hello(name = "World!"):
    print(f"Dear {name.title()}")
    print("Welcome to Python!")


print_hello()
# Out:
# Dear World!
# Welcome to Python!

# %%
# !tree --version || apt install tree
# Out:
# /bin/bash: line 1: tree: command not found
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   tree
# 0 upgraded, 1 newly installed, 0 to remove and 45 not upgraded.
# Need to get 47.9 kB of archives.
# After this operation, 116 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tree amd64 2.0.2-1 [47.9 kB]
# Fetched 47.9 kB in 1s (60.9 kB/s)
# Selecting previously unselected package tree.
# (Reading database ... 123594 files and directories currently installed.)
# Preparing to unpack .../tree_2.0.2-1_amd64.deb ...
# Unpacking tree (2.0.2-1) ...
# Setting up tree (2.0.2-1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# !pip install jupyter_bokeh
# Out:
# ...
#   Using cached jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.6/148.6 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.4/139.4 kB 10.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 29.6 MB/s eta 0:00:00
# Using cached jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
# ...
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.6.8
#     Uninstalling widgetsnbextension-3.6.8:
#       Successfully uninstalled widgetsnbextension-3.6.8
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.7.1
#     Uninstalling ipywidgets-7.7.1:
#       Successfully uninstalled ipywidgets-7.7.1
# ...

# %%
import panel as pn

pn.config.css_files = ["https://cdn.jsdelivr.net/npm/bootstrap@5.3.3/dist/css/bootstrap.min.css"]

pn.config.raw_js = {
    "bootstrap": "https://cdn.jsdelivr.net/npm/bootstrap@5.3.3/dist/js/bootstrap.bundle.min.js"
}

# %%
from collections import defaultdict

def get_card_video(title: str, video_url: str, body_text: str, btn_info: defaultdict):

    iframe = """
    <iframe class="{class_str}" width="560" height="315" src="{video_url}" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen>
    </iframe>
    """

    # <img src="..." class="card-img-top" alt="...">
    card = pn.panel(f"""
    <div class="card" style="width: 35rem;">
            <iframe class="card-img-top" width="560" height="315" src="{video_url}" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen>
        </iframe>
        <div class="card-body">
            <h5 class="card-title">{title}</h5>
            <p class="card-text">
                {body_text}
            </p>
            <p class="text-center">
                <a href="{btn_info["url"]}" class="btn btn-primary text-center px-4 py-2" target="_blank">{btn_info["text"]}</a>
            </p>
        </div>
    </div>
    """)
    return card



pn.extension("plotly", design="material")

video_card = get_card_video(title = "LTSpice Tutorial: Noise Simulations",
               video_url = "https://www.youtube.com/embed/Dh5XmFXlljI?si=zmpafyEGF2WaahNb",
               body_text = "LTSpice Tutorial",
               btn_info = {
                   "url": "https://youtu.be/Dh5XmFXlljI?si=bGShE8e7vBr1yXxg",
                   "text": "Watch YouTube"
               })

header = pn.panel('<h1 class="text-center text-primary mx-auto my-4">LTSPice</h1>')

# pn.Column(header, video_card).servable()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='0ecb03f7-229d-4bf8-bfda-ccf5325d87a9'>
#   <div id="bdff7228-378e-42ab-bdeb-9f0e9f2e1d25" data-root-id="0ecb03f7-229d-4bf8-bfda-ccf5325d87a9" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %% [markdown]
# ## Introduction

# %% [markdown]
# ### Installation
#
# - https://www.analog.com/en/resources/design-tools-and-calculators/ltspice-simulator.html
# -

# %%
# %%html
#
# <iframe width="560" height="315" src="https://www.youtube.com/embed/videoseries?si=Pheg7mmm84TSV2xO&amp;list=PLGtyXSn57qnKRiIqfpVK3ZtzOD8eb_2ro" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/videoseries?si=Pheg7mmm84TSV2xO&amp;list=PLGtyXSn57qnKRiIqfpVK3ZtzOD8eb_2ro" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %% [markdown]
# ### LTSpice: Cheatsheet and keyboard shortcuts
#
# - [analog: LTSpice CheatSheet and keyboard shortcuts](https://www.analog.com/media/en/news-marketing-collateral/solutions-bulletins-brochures/ltspice-keyboard-shortcuts.pdf?modelType=spice-models)

# %% [markdown]
# ### Getting Started with LTSpice

# %%
# <iframe width="560" height="315" src="https://www.youtube.com/embed/bOzKJr62Uc8?si=G4KiWg8yCmAfe-oZ" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

ltspice_symbol_card = get_card_video(
    title = "Getting Started with LTSpice",
    video_url = "https://www.youtube.com/embed/bOzKJr62Uc8?si=G4KiWg8yCmAfe-oZ",
    body_text = "Getting Started with LTSpice: Working with Symbols",
    btn_info = {
        "url": "https://youtu.be/bOzKJr62Uc8?si=G4KiWg8yCmAfe-oZ",
        "text": "Watch YouTube"
    }

)

ltspice_symbol_card.servable()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# Markdown(str, design=<class 'panel.theme.materi...)

# %%
# !apt install tree
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   tree
# 0 upgraded, 1 newly installed, 0 to remove and 45 not upgraded.
# Need to get 47.9 kB of archives.
# After this operation, 116 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tree amd64 2.0.2-1 [47.9 kB]
# Fetched 47.9 kB in 0s (144 kB/s)
# Selecting previously unselected package tree.
# (Reading database ... 123595 files and directories currently installed.)
# Preparing to unpack .../tree_2.0.2-1_amd64.deb ...
# Unpacking tree (2.0.2-1) ...
# Setting up tree (2.0.2-1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %% [markdown]
# ### Folder Structure

# %%
# %%shell
#
# # set -euo pipefile
#
#
# [ ! -d /content/vb/projects/inv ] && rm -rf /content/vb/projects/inv
# # directory structure
# [ ! -d /content/vb/projects/inv ] && mkdir -p /content/vb/projects/inv/{inv1x,inv1x_tb,docs,models}
#
# # files
# files="inv1x.sp inv1x.sym inv1x.cir"
# for file in $files; do
#   [[ ! -f /content/vb/projects/inv/inv1x/$file ]] && touch /content/vb/projects/inv/inv1x/$file
# done
#
# # models
# touch /content/vb/projects/inv/models/{bsim4,tsmc018.lib}
#
# # testbench
# touch /content/vb/projects/inv/inv1x_tb/{inv1x_tb_dcsweep_transfer.sp,inv1x_tb_tran_pulse.sp}
#
# # docs
# touch /content/vb/projects/inv/docs/inv1x.md
# touch /content/vb/projects/inv/README.md
#
# # touch /content/vb/projects/inv/inv1x/{inv1x.sp,inv1x.sym}
# tree /content/vb/projects/inv
#
# exit 0
# Out:
# /content/vb/projects/inv
# ├── docs
# │   └── inv1x.md
# ├── inv1x
# │   ├── inv1x.cir
# │   ├── inv1x.sp
# │   └── inv1x.sym
# ├── inv1x_tb
# │   ├── inv1x_tb_dcsweep_transfer.sp
# │   └── inv1x_tb_tran_pulse.sp
# ├── models
# │   ├── bsim4
# │   └── tsmc018.lib
# └── README.md
#
# 4 directories, 9 files

# %%
# %%writefile ams_project_structure.sh
#
# #!/usr/bin/env bash
#
# %%shell
#
# # set -euo pipefile
#
# # TODO: Add arguments
# CELLNAME="$1"
#
# # [ ! -d ./inv ] && rm -rf ./inv
# # directory structure
# [ ! -d ./inv ] && mkdir -p ./inv/{inv1x,inv1x_tb,docs,models}
#
# echo "Creating files and folders"
# # files
# files="inv1x.sp inv1x.sym inv1x.cir"
# for file in $files; do
#   [[ ! -f ./inv/inv1x/$file ]] && touch ./inv/inv1x/$file
# done
#
# # models
# touch ./inv/models/{bsim4,tsmc018.lib}
#
# # testbench
# touch ./inv/inv1x_tb/{inv1x_tb_dcsweep_transfer.sp,inv1x_tb_tran_pulse.sp}
#
# # docs
# touch ./inv/docs/inv1x.md
# touch ./inv/README.md
#
# # touch ./inv/inv1x/{inv1x.sp,inv1x.sym}
# tree ./inv
#
# exit 0
# Out:
# Overwriting ams_project_structure.sh

# %%
# !cd projects && chmod u+x ../ams_project_structure.sh && ../ams_project_structure.sh inv1x
# Out:
# ../ams_project_structure.sh: line 4: fg: no job control
# Creating files and folders
# touch: cannot touch './inv/models/bsim4': No such file or directory
# touch: cannot touch './inv/models/tsmc018.lib': No such file or directory
# touch: cannot touch './inv/inv1x_tb/inv1x_tb_dcsweep_transfer.sp': No such file or directory
# touch: cannot touch './inv/inv1x_tb/inv1x_tb_tran_pulse.sp': No such file or directory
# ./inv
# ├── docs
# │   └── inv1x.md
# ├── inv1x
# │   ├── inv1x.cir
# │   ├── inv1x.sp
# │   └── inv1x.sym
# ├── README.md
# └── testbench
#
# 3 directories, 5 files

# %% [markdown]
# ## Examples

# %% [markdown]
# ### Digital Gates

# %% [markdown]
# <!-- <figure align="center">
# <img src="https://learnabout-electronics.org/Digital/images/Gate%20Symbols.jpg" alt="Digital Gate Symbols"/>
# </figure> -->
#
# <figure align="center">
# <img src="https://miro.medium.com/v2/resize:fit:1070/1*MtGO2DVCyEf3abN4M1oeIw.png" alt="Digital Gate Symbols" width="40%" height="40%"/>
# </figure>

# %% [markdown]
# ### CMOS Inverter

# %% [markdown]
# ### Schematic

# %% [markdown]
# ![Inverter Schematic](https://www.elprocus.com/wp-content/uploads/CMOS-Inverter-Symbol-Truth-Table.jpg)
# ![Inverter Schematic](https://www.elprocus.com/wp-content/uploads/CMOS-Inverter-Circuit.png)

# %%
# <iframe width="560" height="315" src="https://www.youtube.com/embed/7fgR677XPPA?si=tEZQBuLSOJQTz07R" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

inv_sch = get_card_video(
    title = "Inverter: Schematic and Symbol",
    video_url = "https://www.youtube.com/embed/7fgR677XPPA?si=tEZQBuLSOJQTz07R",
    body_text = "Inverter: Schematic",
    btn_info = {
        "url": "https://youtu.be/7fgR677XPPA?si=UEntT4iBijFfleyc",
        "text": "Watch YouTube"
    }

)

inv_sch.servable().servable()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# Markdown(str, design=<class 'panel.theme.materi...)

# %% [markdown]
# ### DC Sweep: Transfer Characteristics
#
# ![Inverter: transfer Characteristics](https://www.elprocus.com/wp-content/uploads/Voltage-Transfer-Curve.jpg)

# %% [markdown]
# ### Transient
#
#
# ![Inverter: transient](https://www.elprocus.com/wp-content/uploads/Dynamic-Characteristics-of-CMOS-Inverter.jpg)

# %% [markdown]
# Calculation of Inverter Capacitance

# %%
# <iframe width="560" height="315" src="https://www.youtube.com/embed/2yi-mwjHoqU?si=YPtUI_BVxdqRIItv" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

inverter_dynamic_behavior = get_card_video(
    title = "Inverter: Dynamic Behacior",
    video_url = "https://www.youtube.com/embed/2yi-mwjHoqU?si=YPtUI_BVxdqRIItv",
    body_text = "Inverter: transient",
    btn_info = {
        "url": "https://youtu.be/2yi-mwjHoqU?si=wPU0AQYHtVBQ-W1w",
        "text": "Watch YouTube"
    }

)

inverter_dynamic_behavior.servable()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# Markdown(str, design=<class 'panel.theme.materi...)

# %% [markdown]
# ### NAND and NOR Gates

# %% [markdown]
# ### NAND Gate
#
# <p align="center">
#
# <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcST6xeA96KsLwtFcHO4thhxX-jPnhvAsEPNOw&s"/>
#
# </p>
#
# <p align="center">
#
# <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSwI8aZT8ArNsmQx_N6QGU9DBHPRC3ro2eIyQ&s"/>
#
# </p>
#
#
# ### NOR Gate
#
# <p align="center">
#
# <img src="https://i.ytimg.com/vi/05ef3BDmT_8/maxresdefault.jpg" width = "400px" height="200px" alt="NOR Gate"/>
#
# </p>
#
#
# <p align="center">
#
# <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQYcti4K9YX62Fm3wQKvI1OJBmoKe7VltE2EQ&s" width = "300px" height="400px" alt="NOR Gate"/>
#
# </p>

# %%
# %%html

# <iframe width="560" height="315" src="https://www.youtube.com/embed/4ew1GI_b23M?si=vkd4VGRtIVWzZzyz" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %%
nand_nor_card = get_card_video(
    title = "NAND and NOR Simulations with LTSpice",
    video_url = "https://www.youtube.com/embed/4ew1GI_b23M?si=vkd4VGRtIVWzZzyz",
    body_text = "NAND and NOR Simulations with LTSpice",
    btn_info = {
        "url": "https://youtu.be/4ew1GI_b23M?si=rgmYfkULr3bep9Im",
        "text": "Watch YouTube"
    }

)

nand_nor_card.servable()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# Markdown(str, design=<class 'panel.theme.materi...)

# %% [markdown]
# ### CMOS Full Adder

# %%
# <iframe width="560" height="315" src="https://www.youtube.com/embed/AXU_J4wr_yA?si=3AjTSH-EoUG9F6dZ" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

full_adder_card = get_card_video(
    title = "CMOS Full Adder",
    video_url = "https://www.youtube.com/embed/AXU_J4wr_yA?si=3AjTSH-EoUG9F6dZ",
    body_text = "CMOS Full Adder",
    btn_info = {
        "url": "https://youtu.be/AXU_J4wr_yA?si=3AjTSH-EoUG9F6dZ",
        "text": "Watch YouTube"
    }
)

full_adder_card.servable()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# Markdown(str, design=<class 'panel.theme.materi...)

# %% [markdown]
# ### Single-Endded Differential Amplifier
#
# <div>
#     <iframe width="560" height="315" src="https://www.youtube.com/embed/_qKFQ1H_zOI?si=KwUOI40vC0VF-5j3" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
# </div>

# %%
video_card = get_card_video(title = "LTSpice Tutorial",
               video_url = "https://www.youtube.com/embed/_qKFQ1H_zOI?si=Fu7FqjEpiT7OWlyv",
               body_text = "LTSpice Tutorial",
               btn_info = {
                   "url": "https://youtu.be/_qKFQ1H_zOI?si=A7Eu4GvdUvJbfrRD",
                   "text": "Watch YouTube"
               })
video_card.servable()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# Markdown(str, design=<class 'panel.theme.materi...)

# %% [markdown]
# ## Appendix

# %% [markdown]
# ### Technology
#
# - https://sanjayvidhyadharan.in/Downloads/
#     - tsmc018
# - Jacob Baker
#     - [C5_models](https://cmosedu.com/jbaker/courses/ee421_ecg621/f23/C5_models.txt)
# -

# %% [markdown]
# ### Panel

# %%
# !pip install jupyter_bokeh

# %% [markdown]
# bootstrap
#
# ```html
# <link href="https://cdn.jsdelivr.net/npm/bootstrap@5.3.3/dist/css/bootstrap.min.css" rel="stylesheet" integrity="sha384-QWTKZyjpPEjISv5WaRU9OFeRpok6YctnYmDr5pNlyT2bRjXh0JMhjY6hW+ALEwIH" crossorigin="anonymous">
#
#
# <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.3.3/dist/js/bootstrap.bundle.min.js" integrity="sha384-YvpcrYf0tY3lHB60NNkmXc5s9fDVZLESaAA55NDzOxhy9GkcIdslK1eN7N6jIeHz" crossorigin="anonymous"></script>
#
# ```

# %% [markdown]
# ### A: Montecarlo
#
# - [Monte Carlo](https://youtu.be/iyXJ6GMj4qc?si=XkXgxdfCx9Dgmapq)
# - [YouTube/Way2Know: Monte Carlo Simulation in LTspice | LTspice tutorial](https://youtu.be/iyXJ6GMj4qc?si=M0uJCpfM7G9fcHcv)
# - [Noise Simulations](https://youtu.be/Dh5XmFXlljI?si=avN9DKmW0AT9u09T)

# %%
import panel as pn

pn.config.css_files = ["https://cdn.jsdelivr.net/npm/bootstrap@5.3.3/dist/css/bootstrap.min.css"]

pn.config.raw_js = {
    "bootstrap": "https://cdn.jsdelivr.net/npm/bootstrap@5.3.3/dist/js/bootstrap.bundle.min.js"
}

# %%
from collections import defaultdict

def get_card_video(title: str, video_url: str, body_text: str, btn_info: defaultdict):

    iframe = """
    <iframe class="{class_str}" width="560" height="315" src="{video_url}" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen>
    </iframe>
    """

    # <img src="..." class="card-img-top" alt="...">
    card = pn.panel(f"""
    <div class="card" style="width: 35rem;">
            <iframe class="card-img-top" width="560" height="315" src="{video_url}" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen>
        </iframe>
        <div class="card-body">
            <h5 class="card-title">{title}</h5>
            <p class="card-text">
                {body_text}
            </p>
            <p class="text-center">
                <a href="{btn_info["url"]}" class="btn btn-primary text-center px-4 py-2">{btn_info["text"]}</a>
            </p>
        </div>
    </div>
    """)
    return card



pn.extension("plotly", design="material")

video_card = get_card_video(title = "LTSpice Tutorial",
               video_url = "https://www.youtube.com/embed/Dh5XmFXlljI?si=zmpafyEGF2WaahNb",
               body_text = "LTSpice Tutorial",
               btn_info = {
                   "url": "https://youtu.be/Dh5XmFXlljI?si=bGShE8e7vBr1yXxg",
                   "text": "Watch YouTube"
               })
video_card2 = get_card_video(title = "LTSpice Tutorial",
               video_url = "https://youtu.be/iyXJ6GMj4qc?si=FBTsq9CP6CzuBbP-",
               body_text = "LTSpice Tutorial",
               btn_info = {
                   "url": "https://youtu.be/Dh5XmFXlljI?si=bGShE8e7vBr1yXxg",
                   "text": "Watch YouTube"
               })
header = pn.panel('<h1 class="text-center text-primary mx-auto my-4">Card Title</h1>')

pn.Column(header, video_card, video_card2).servable()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='13a97e2b-bf49-44cc-914d-5057276fabcb'>
#   <div id="c36914b2-5e62-480f-947c-50f6ed59f3b8" data-root-id="13a97e2b-bf49-44cc-914d-5057276fabcb" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %% [markdown]
# ### A: Digital CMOS IC Design

# %%
# <iframe width="560" height="315" src="https://www.youtube.com/embed/videoseries?si=0yeGM7XJatfoe6bp&amp;list=PLBDB2c4Mp7hBLRcEpE19yyHB-zKzsyp_4" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

basic_vlsi_card = get_card_video(
    title = "Digital CMOS IC Design",
    video_url = "https://www.youtube.com/embed/videoseries?si=0yeGM7XJatfoe6bp&amp;list=PLBDB2c4Mp7hBLRcEpE19yyHB-zKzsyp_4",
    body_text = "Digital CMOS IC Design",
    btn_info = {
        "url": "https://youtube.com/playlist?list=PLBDB2c4Mp7hBLRcEpE19yyHB-zKzsyp_4&si=Lmh1D6XWEkhyDNQy",
        "text": "Watch YouTube"
    }

)

basic_vlsi_card.servable()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# Markdown(str, design=<class 'panel.theme.materi...)

# %% [markdown]
# ### YouTube/Marcos Alonso:

# %%
# <iframe width="560" height="315" src="https://www.youtube.com/embed/videoseries?si=rtd9qESvbfN-jaHK&amp;list=PLq_MUr0hT_-lfiWvcRfPpbNcjzGHhPuPl" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

ltspice_card = get_card_video(
    title = "LTSpice",
    video_url = "https://www.youtube.com/embed/videoseries?si=rtd9qESvbfN-jaHK&amp;list=PLq_MUr0hT_-lfiWvcRfPpbNcjzGHhPuPl",
    body_text = "LTSpice",
    btn_info = {
        "url": "https://youtube.com/playlist?list=PLq_MUr0hT_-lfiWvcRfPpbNcjzGHhPuPl&si=rtd9qESvbfN-jaHK&amp;list=PLq_MUr0hT_-lfiWvcRfPpbNcjzGHhPuPl",
        "text": "Watch YouTube"
    }

)

ltspice_card.servable()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# Markdown(str, design=<class 'panel.theme.materi...)

# %% [markdown]
# ### YouTUbe/Mateo Aboy: Analog

# %%
# <iframe width="560" height="315" src="https://www.youtube.com/embed/videoseries?si=Kq2-Gr4n6ib_aXHA&amp;list=PLZvLSclgk4yIGlxyGZsLSyJTiEY4_70Fj" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

ltspice_analog_card = get_card_video(
    title = "YouTUbe/Mateo Aboy: LTSpice Analog",
    video_url = "https://www.youtube.com/embed/videoseries?si=Kq2-Gr4n6ib_aXHA&amp;list=PLZvLSclgk4yIGlxyGZsLSyJTiEY4_70Fj",
    body_text = "LTSpice Analog",
    btn_info = {
        "url": "https://youtube.com/playlist?list=PLZvLSclgk4yIGlxyGZsLSyJTiEY4_70Fj&si=Kq2-Gr4n6ib_aXHA&amp;list=PLZvLSclgk4yIGlxyGZsLSyJTiEY4_70Fj",
        "text": "Watch YouTube"
    }

)

ltspice_analog_card.servable()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# Markdown(str, design=<class 'panel.theme.materi...)
